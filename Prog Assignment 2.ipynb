# %%
# import libraries

from bs4 import BeautifulSoup
import re
import sys
from nltk.util import ngrams
from nltk import ConditionalFreqDist
from nltk.stem.snowball import SnowballStemmer
from nltk.probability import ConditionalProbDist, ELEProbDist
from collections import defaultdict

# %%
# Function to process XML files using BeautifulSoup

def process_xml_file(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
    soup = BeautifulSoup(content, 'xml')
    return soup

### CHANGE TO YOUR PATH ###

desktop_path = '/Users/viruthika/Desktop'
file1_path = os.path.join(desktop_path, 'line-test.xml')
file2_path = os.path.join(desktop_path, 'line-train.xml')

soup1 = process_xml_file(file1_path)
soup2 = process_xml_file(file2_path)

# %%
# Preprocess the train and test data by converting to lowercase, standardizing plural lines, 
# and removing special characters

def preprocess_data(soup):
    instances = soup.find_all('instance')
    data_dict = {}
    
    for instance in instances:
        instance_id = instance['id']
        answer = instance.find('answer')
        if answer:
            sense = answer['senseid']
        else:
            sense = " "
        # try context = instance.get_text() if below doesn't work # 
        context = instance.context.get_text()
        
        context = context.lower()
        context = re.sub(r'[^\w\s]', ' ', context)
        
        tokens = context.split()
        stemmer = SnowballStemmer('english')
        stemmed_tokens = [stemmer.stem(token) for token in tokens]
        context = ' '.join(stemmed_tokens)
        
#3 Create a dictionary with id, sense, and list of tokens to use for further operations        
        data_dict[instance_id] = {'sense': sense, 'tokens': stemmed_tokens}
        
    return data_dict

# %%
# Function to create decision list

def create_decision_list(train_data):
    cfdist = ConditionalFreqDist()
    
    #iterate over data and update cfdist
    for instance_id, data in train_data.items():
        sense = data['sense']
        tokens = data['tokens']
        
        # window size two words to the left, one word to the right
        for i, token in enumerate(tokens):
            if token == 'line':
                left_tokens = tokens[i - 2:i] if i >= 2 else tokens[:1]
                right_tokens = tokens[i + 1:i + 2]
                
                for lt in left_tokens:
                    cfdist[sense][lt] += 1
                for rt in right_tokens:
                    cfdist[sense][rt] += 1
                    
    cpdist = ConditionalProbDist(cfdist, ELEProbDist, bins = 290)
    print(cpdist['run'].max)
    print(cpdist['run'].prob('NN'))
    
    pdists = {}
    for sense in cfdist:
        fd = cfdist[sense]
        pd = ELEProbDist(fd)
        pdists[sense] = pd
                          
    # print decision list
    for sense, freqdist in cfdist.items():
        print(f"Senses: {sense}")
        for word, freq in freqdist.items():
            print(f"\tWord: {word} Frequency: {freq}")
        
    return cfdist

# %%
# apply decision list to test data and write output to predicted_labels_file

def apply_decision_list(decision_list, test_data):
    predicted_labels = {}
    
    # iterate over test instances and predict label using decision tree
    for instance_id, data in test_data.items():
        tokens = data['tokens']
        label = None
        max_freq = 0
        
        # iterate over senes in dec. list and find the sense with highest freq
        for sense, freqdist in decision_list.items():
            freq = 0
            for token in tokens:
                freq += freqdist[token]
            if freq > max_freq:
                label = sense
                max_freq = freq
                
        predicted_labels[instance_id] = label
        
    with open(predicted_labels_file, 'w') as f:
        for instance_id, label in predicted_labels.items():
            f.write(instance_id + ' ' + label + '\n')
    print(predicted_labels)

# %%
# main function to call process_xml, preprocess_data, and apply_decision_list
# export decision list as text file

def main(train_file, test_file, decision_list_file, predicted_labels_file):
    train_soup = process_xml_file(train_file)
    test_soup = process_xml_file(test_file)
    
    train_data = preprocess_data(train_soup)
    test_data = preprocess_data(test_soup)
    
    decision_list = create_decision_list(train_data)
    predicted_labels = apply_decision_list(decision_list, test_data)
    
    with open(decision_list_file, 'w') as f:
        for instance_id, data in train_data.items():
            sense = data['sense']
            tokens = ' '.join(data['tokens'])
            
            f.write(f'<answer instance="{instance_id}" senseid="{sense}"/>\n')
            
# specifiy file names

"""if __name__ == '__main__':
    
    train_file = 'line-train.xml'
    test_file = 'line-test.xml'
    
    decision_list_file = 'my-line-answers.txt'
    predicted_labels_file = 'my-predicted-labels.txt'
    
    main(train_file, test_file, decision_list_file, predicted_labels_file)"""

if __name__ == '__main__':
    desktop_path = '/Users/viruthika/Desktop'

    train_file = os.path.join(desktop_path, 'line-train.xml')
    test_file = os.path.join(desktop_path, 'line-test.xml')
    decision_list_file = os.path.join(desktop_path, 'my-line-answers.txt')
    predicted_labels_file = os.path.join(desktop_path, 'my-predicted-labels.txt')

    main(train_file, test_file, decision_list_file, predicted_labels_file)
# Out:
# <bound method LidstoneProbDist.max of <ELEProbDist based on 0 samples>>
# 0.0034482758620689655
# Senses: phone
# 	Word: 5 Frequency: 1
# 	Word: access Frequency: 19
# 	Word: growth Frequency: 3
# 	Word: 000 Frequency: 8
# 	Word: new Frequency: 13
# 	Word: to Frequency: 21
# 	Word: on Frequency: 26
# 	Word: the Frequency: 77
# 	Word: gab Frequency: 8
# 	Word: have Frequency: 2
# 	Word: telephon Frequency: 42
# 	Word: tip Frequency: 3
# 	Word: that Frequency: 9
# 	Word: trader Frequency: 1
# 	Word: thousand Frequency: 2
# 	Word: keep Frequency: 3
# 	Word: busi Frequency: 5
# 	Word: residenti Frequency: 2
# 	Word: increas Frequency: 4
# 	Word: cellular Frequency: 1
# 	Word: mobil Frequency: 1
# 	Word: grew Frequency: 5
# 	Word: distanc Frequency: 1
# 	Word: or Frequency: 3
# 	Word: dedic Frequency: 3
# 	Word: make Frequency: 2
# 	Word: privat Frequency: 7
# 	Word: and Frequency: 26
# 	Word: switch Frequency: 1
# 	Word: was Frequency: 12
# 	Word: an Frequency: 4
# 	Word: outsid Frequency: 2
# 	Word: up Frequency: 1
# 	Word: but Frequency: 3
# 	Word: largest Frequency: 1
# 	Word: 371 Frequency: 1
# 	Word: instal Frequency: 2
# 	Word: over Frequency: 6
# 	Word: use Frequency: 2
# 	Word: as Frequency: 2
# 	Word: 24 Frequency: 1
# 	Word: 32 Frequency: 1
# 	Word: of Frequency: 18
# 	Word: s Frequency: 2
# 	Word: bisexu Frequency: 1
# 	Word: recent Frequency: 2
# 	Word: york Frequency: 1
# 	Word: free Frequency: 4
# 	Word: complaint Frequency: 1
# 	Word: necessari Frequency: 1
# 	Word: toll Frequency: 1
# 	Word: for Frequency: 9
# 	Word: their Frequency: 2
# 	Word: trade Frequency: 3
# 	Word: yesterday Frequency: 1
# 	Word: first Frequency: 1
# 	Word: off Frequency: 3
# 	Word: phone Frequency: 1
# 	Word: whose Frequency: 2
# 	Word: into Frequency: 1
# 	Word: open Frequency: 5
# 	Word: radio Frequency: 1
# 	Word: you Frequency: 1
# 	Word: unsecur Frequency: 1
# 	Word: while Frequency: 2
# 	Word: public Frequency: 1
# 	Word: is Frequency: 5
# 	Word: let Frequency: 1
# 	Word: see Frequency: 1
# 	Word: light Frequency: 1
# 	Word: when Frequency: 1
# 	Word: come Frequency: 1
# 	Word: pay Frequency: 1
# 	Word: subscrib Frequency: 3
# 	Word: charg Frequency: 3
# 	Word: four Frequency: 1
# 	Word: hullo Frequency: 1
# 	Word: were Frequency: 5
# 	Word: a Frequency: 13
# 	Word: dead Frequency: 1
# 	Word: fuqua Frequency: 1
# 	Word: provid Frequency: 1
# 	Word: fanci Frequency: 1
# 	Word: earthquak Frequency: 1
# 	Word: will Frequency: 1
# 	Word: 900 Frequency: 1
# 	Word: call Frequency: 2
# 	Word: other Frequency: 2
# 	Word: he Frequency: 1
# 	Word: custom Frequency: 3
# 	Word: clog Frequency: 4
# 	Word: just Frequency: 1
# 	Word: dozen Frequency: 1
# 	Word: at Frequency: 3
# 	Word: your Frequency: 1
# 	Word: direct Frequency: 5
# 	Word: no Frequency: 2
# 	Word: in Frequency: 12
# 	Word: resid Frequency: 1
# 	Word: calif Frequency: 1
# 	Word: onc Frequency: 1
# 	Word: dial Frequency: 1
# 	Word: 700 Frequency: 1
# 	Word: proprietor Frequency: 1
# 	Word: say Frequency: 4
# 	Word: went Frequency: 3
# 	Word: this Frequency: 1
# 	Word: lost Frequency: 1
# 	Word: from Frequency: 1
# 	Word: between Frequency: 1
# 	Word: 10 Frequency: 1
# 	Word: million Frequency: 3
# 	Word: if Frequency: 2
# 	Word: it Frequency: 1
# 	Word: said Frequency: 1
# 	Word: romanc Frequency: 1
# 	Word: 570 Frequency: 2
# 	Word: main Frequency: 2
# 	Word: i Frequency: 1
# 	Word: edmonton Frequency: 1
# 	Word: one Frequency: 2
# 	Word: quadrupl Frequency: 1
# 	Word: 866 Frequency: 1
# 	Word: all Frequency: 1
# 	Word: parti Frequency: 4
# 	Word: some Frequency: 1
# 	Word: certain Frequency: 1
# 	Word: local Frequency: 1
# 	Word: with Frequency: 2
# 	Word: cross Frequency: 1
# 	Word: by Frequency: 2
# 	Word: they Frequency: 2
# 	Word: becaus Frequency: 1
# 	Word: effect Frequency: 1
# 	Word: get Frequency: 2
# 	Word: voic Frequency: 2
# 	Word: anoth Frequency: 2
# 	Word: most Frequency: 1
# 	Word: import Frequency: 1
# 	Word: hardwar Frequency: 1
# 	Word: adapt Frequency: 1
# 	Word: grade Frequency: 1
# 	Word: 1200 Frequency: 1
# 	Word: 600 Frequency: 2
# 	Word: baud Frequency: 1
# 	Word: low Frequency: 1
# 	Word: speed Frequency: 1
# 	Word: 50 Frequency: 1
# 	Word: run Frequency: 1
# 	Word: last Frequency: 1
# 	Word: inform Frequency: 2
# 	Word: which Frequency: 2
# 	Word: through Frequency: 1
# 	Word: includ Frequency: 1
# 	Word: poorest Frequency: 1
# 	Word: so Frequency: 1
# 	Word: foreign Frequency: 1
# 	Word: exchang Frequency: 1
# 	Word: would Frequency: 1
# 	Word: his Frequency: 1
# 	Word: be Frequency: 1
# 	Word: sir Frequency: 1
# 	Word: like Frequency: 2
# 	Word: secur Frequency: 1
# 	Word: more Frequency: 1
# 	Word: accord Frequency: 1
# 	Word: hospit Frequency: 1
# 	Word: dure Frequency: 1
# 	Word: number Frequency: 1
# 	Word: hello Frequency: 1
# 	Word: 442 Frequency: 1
# 	Word: consum Frequency: 1
# 	Word: appeal Frequency: 1
# 	Word: sentenc Frequency: 1
# 	Word: mani Frequency: 1
# 	Word: among Frequency: 1
# 	Word: separ Frequency: 1
# 	Word: 3 Frequency: 1
# 	Word: extend Frequency: 1
# 	Word: seek Frequency: 1
# 	Word: fed Frequency: 1
# 	Word: transact Frequency: 1
# 	Word: also Frequency: 1
# 	Word: time Frequency: 1
# 	Word: asynchron Frequency: 1
# 	Word: check Frequency: 1
# 	Word: x Frequency: 1
# 	Word: rate Frequency: 1
# 	Word: station Frequency: 1
# 	Word: c Frequency: 1
# 	Word: 1 Frequency: 1
# 	Word: 800 Frequency: 1
# 	Word: three Frequency: 1
# 	Word: 911 Frequency: 1
# 	Word: emerg Frequency: 1
# 	Word: play Frequency: 1
# 	Word: noth Frequency: 1
# 	Word: sex Frequency: 1
# 	Word: chat Frequency: 2
# 	Word: ordinari Frequency: 1
# 	Word: jump Frequency: 1
# 	Word: those Frequency: 2
# 	Word: rent Frequency: 1
# 	Word: communic Frequency: 1
# 	Word: are Frequency: 1
# 	Word: nois Frequency: 1
# 	Word: singl Frequency: 1
# Senses: product
# 	Word: establish Frequency: 1
# 	Word: the Frequency: 30
# 	Word: as Frequency: 3
# 	Word: introduc Frequency: 5
# 	Word: in Frequency: 6
# 	Word: struggl Frequency: 1
# 	Word: was Frequency: 1
# 	Word: rang Frequency: 2
# 	Word: comput Frequency: 6
# 	Word: and Frequency: 19
# 	Word: previous Frequency: 1
# 	Word: three Frequency: 2
# 	Word: at Frequency: 4
# 	Word: higher Frequency: 1
# 	Word: margin Frequency: 1
# 	Word: which Frequency: 5
# 	Word: inc Frequency: 1
# 	Word: s Frequency: 21
# 	Word: of Frequency: 65
# 	Word: skin Frequency: 2
# 	Word: care Frequency: 3
# 	Word: is Frequency: 6
# 	Word: certain Frequency: 2
# 	Word: atlas Frequency: 1
# 	Word: furnitur Frequency: 1
# 	Word: could Frequency: 3
# 	Word: microprocessor Frequency: 2
# 	Word: non Frequency: 1
# 	Word: food Frequency: 4
# 	Word: rail Frequency: 1
# 	Word: intermod Frequency: 1
# 	Word: between Frequency: 1
# 	Word: car Frequency: 10
# 	Word: mr Frequency: 1
# 	Word: more Frequency: 1
# 	Word: complet Frequency: 2
# 	Word: luxuri Frequency: 2
# 	Word: may Frequency: 1
# 	Word: jaclyn Frequency: 2
# 	Word: smith Frequency: 2
# 	Word: frozen Frequency: 1
# 	Word: expand Frequency: 1
# 	Word: their Frequency: 1
# 	Word: said Frequency: 2
# 	Word: corp Frequency: 1
# 	Word: a Frequency: 35
# 	Word: similar Frequency: 2
# 	Word: r1 Frequency: 1
# 	Word: made Frequency: 1
# 	Word: launch Frequency: 2
# 	Word: truck Frequency: 1
# 	Word: through Frequency: 3
# 	Word: new Frequency: 15
# 	Word: ibm Frequency: 5
# 	Word: he Frequency: 2
# 	Word: produc Frequency: 3
# 	Word: two Frequency: 3
# 	Word: it Frequency: 24
# 	Word: integr Frequency: 1
# 	Word: popular Frequency: 2
# 	Word: diagnost Frequency: 1
# 	Word: show Frequency: 1
# 	Word: sever Frequency: 1
# 	Word: such Frequency: 2
# 	Word: compani Frequency: 2
# 	Word: volum Frequency: 1
# 	Word: creat Frequency: 1
# 	Word: by Frequency: 3
# 	Word: acquir Frequency: 2
# 	Word: to Frequency: 8
# 	Word: build Frequency: 3
# 	Word: into Frequency: 2
# 	Word: while Frequency: 1
# 	Word: will Frequency: 2
# 	Word: from Frequency: 5
# 	Word: older Frequency: 2
# 	Word: carleton Frequency: 1
# 	Word: brand Frequency: 1
# 	Word: other Frequency: 2
# 	Word: montana Frequency: 1
# 	Word: fragranc Frequency: 1
# 	Word: pc Frequency: 2
# 	Word: wouldn Frequency: 1
# 	Word: out Frequency: 1
# 	Word: aerospac Frequency: 1
# 	Word: seller Frequency: 1
# 	Word: gm Frequency: 2
# 	Word: 10 Frequency: 1
# 	Word: apparel Frequency: 1
# 	Word: that Frequency: 6
# 	Word: those Frequency: 1
# 	Word: were Frequency: 3
# 	Word: 5 Frequency: 1
# 	Word: billion Frequency: 1
# 	Word: cereal Frequency: 2
# 	Word: with Frequency: 4
# 	Word: own Frequency: 1
# 	Word: includ Frequency: 2
# 	Word: tri Frequency: 1
# 	Word: perfum Frequency: 1
# 	Word: elizabeth Frequency: 1
# 	Word: jeep Frequency: 1
# 	Word: 1988 Frequency: 1
# 	Word: model Frequency: 1
# 	Word: this Frequency: 1
# 	Word: brief Frequency: 1
# 	Word: current Frequency: 3
# 	Word: seek Frequency: 1
# 	Word: torpedo Frequency: 1
# 	Word: lastest Frequency: 1
# 	Word: market Frequency: 4
# 	Word: much Frequency: 1
# 	Word: broader Frequency: 1
# 	Word: but Frequency: 3
# 	Word: latest Frequency: 1
# 	Word: adult Frequency: 1
# 	Word: diaper Frequency: 1
# 	Word: most Frequency: 2
# 	Word: product Frequency: 10
# 	Word: particular Frequency: 1
# 	Word: materi Frequency: 2
# 	Word: fell Frequency: 2
# 	Word: florida Frequency: 1
# 	Word: these Frequency: 1
# 	Word: grand Frequency: 1
# 	Word: prix Frequency: 1
# 	Word: ps Frequency: 7
# 	Word: 2 Frequency: 8
# 	Word: his Frequency: 2
# 	Word: full Frequency: 2
# 	Word: under Frequency: 2
# 	Word: are Frequency: 3
# 	Word: cougar Frequency: 1
# 	Word: cracker Frequency: 1
# 	Word: drop Frequency: 1
# 	Word: dreamboat Frequency: 1
# 	Word: patch Frequency: 1
# 	Word: kid Frequency: 1
# 	Word: toy Frequency: 1
# 	Word: remain Frequency: 1
# 	Word: excav Frequency: 1
# 	Word: equip Frequency: 2
# 	Word: american Frequency: 1
# 	Word: tire Frequency: 1
# 	Word: 1 Frequency: 1
# 	Word: 69 Frequency: 1
# 	Word: midrang Frequency: 1
# 	Word: 400 Frequency: 1
# 	Word: menswear Frequency: 1
# 	Word: had Frequency: 1
# 	Word: jewelri Frequency: 1
# 	Word: athlet Frequency: 1
# 	Word: shoe Frequency: 1
# 	Word: 600 Frequency: 1
# 	Word: camera Frequency: 1
# 	Word: women Frequency: 1
# 	Word: where Frequency: 1
# 	Word: 32 Frequency: 1
# 	Word: built Frequency: 1
# 	Word: restaur Frequency: 1
# 	Word: sun Frequency: 1
# 	Word: choic Frequency: 1
# 	Word: softwar Frequency: 1
# 	Word: pace Frequency: 1
# 	Word: macintosh Frequency: 1
# 	Word: rose Frequency: 1
# 	Word: mirag Frequency: 1
# 	Word: amiga Frequency: 1
# 	Word: spectrum Frequency: 1
# 	Word: has Frequency: 2
# 	Word: ii Frequency: 1
# 	Word: move Frequency: 1
# 	Word: call Frequency: 1
# 	Word: old Frequency: 3
# 	Word: for Frequency: 6
# 	Word: ziari Frequency: 1
# 	Word: manufactur Frequency: 1
# 	Word: special Frequency: 1
# 	Word: broaden Frequency: 1
# 	Word: lexus Frequency: 1
# 	Word: upscal Frequency: 1
# 	Word: reap Frequency: 1
# 	Word: becaus Frequency: 2
# 	Word: minicomput Frequency: 1
# 	Word: along Frequency: 1
# 	Word: soft Frequency: 1
# 	Word: drink Frequency: 1
# 	Word: just Frequency: 1
# 	Word: offic Frequency: 1
# 	Word: chevrolet Frequency: 1
# 	Word: corsica Frequency: 1
# 	Word: credit Frequency: 2
# 	Word: bank Frequency: 1
# 	Word: discontinu Frequency: 1
# 	Word: loss Frequency: 1
# 	Word: consist Frequency: 1
# 	Word: specialti Frequency: 1
# 	Word: read Frequency: 1
# 	Word: last Frequency: 2
# 	Word: transform Frequency: 1
# 	Word: tonka Frequency: 1
# 	Word: pound Frequency: 1
# 	Word: puppi Frequency: 1
# 	Word: clarion Frequency: 1
# 	Word: have Frequency: 3
# 	Word: agricultur Frequency: 1
# 	Word: machineri Frequency: 1
# 	Word: all Frequency: 1
# 	Word: some Frequency: 3
# 	Word: dr Frequency: 1
# 	Word: denton Frequency: 1
# 	Word: lucrat Frequency: 1
# 	Word: militari Frequency: 1
# 	Word: georg Frequency: 1
# 	Word: long Frequency: 1
# 	Word: await Frequency: 1
# 	Word: basic Frequency: 1
# 	Word: chemic Frequency: 1
# 	Word: nail Frequency: 1
# 	Word: polish Frequency: 1
# 	Word: an Frequency: 1
# 	Word: exclus Frequency: 1
# 	Word: make Frequency: 2
# 	Word: main Frequency: 1
# 	Word: oh Frequency: 1
# 	Word: lantern Frequency: 1
# 	Word: 375 Frequency: 1
# 	Word: plan Frequency: 1
# 	Word: pw4000 Frequency: 1
# 	Word: start Frequency: 1
# 	Word: shed Frequency: 1
# 	Word: consum Frequency: 2
# 	Word: there Frequency: 1
# 	Word: person Frequency: 1
# 	Word: won Frequency: 1
# 	Word: sew Frequency: 1
# 	Word: they Frequency: 1
# 	Word: health Frequency: 1
# 	Word: club Frequency: 1
# 	Word: balli Frequency: 1
# 	Word: coleco Frequency: 1
# 	Word: drill Frequency: 1
# 	Word: bit Frequency: 1
# 	Word: baker Frequency: 1
# 	Word: zytel Frequency: 1
# 	Word: nation Frequency: 1
# 	Word: advertis Frequency: 1
# 	Word: initi Frequency: 1
# 	Word: filter Frequency: 1
# 	Word: vax Frequency: 2
# 	Word: cray Frequency: 1
# 	Word: reason Frequency: 1
# 	Word: price Frequency: 1
# 	Word: exist Frequency: 2
# 	Word: dps Frequency: 1
# 	Word: alreadi Frequency: 1
# 	Word: huge Frequency: 1
# 	Word: schaffner Frequency: 1
# 	Word: marx Frequency: 1
# 	Word: on Frequency: 1
# 	Word: so Frequency: 2
# 	Word: sell Frequency: 1
# 	Word: optometr Frequency: 1
# 	Word: ground Frequency: 1
# 	Word: coffe Frequency: 1
# 	Word: she Frequency: 1
# 	Word: level Frequency: 1
# 	Word: fox Frequency: 1
# 	Word: low Frequency: 1
# 	Word: calori Frequency: 1
# 	Word: sturdi Frequency: 1
# 	Word: 3x Frequency: 1
# 	Word: one Frequency: 1
# 	Word: test Frequency: 1
# 	Word: futur Frequency: 1
# 	Word: hormel Frequency: 1
# 	Word: anymor Frequency: 1
# 	Word: lancom Frequency: 1
# {'line-n.w8_059:8174:': 'phone', 'line-n.w7_098:12684:': 'phone', 'line-n.w8_106:13309:': 'phone', 'line-n.w9_40:10187:': 'phone', 'line-n.w9_16:217:': 'product', 'line-n.w8_119:16927:': 'product', 'line-n.w8_008:13756:': 'phone', 'line-n.w8_041:15186:': 'phone', 'line-n.art7} aphb 05601797:': 'phone', 'line-n.w8_119:2964:': 'phone', 'line-n.w7_040:13652:': 'phone', 'line-n.w7_122:2194:': 'phone', 'line-n.art7} aphb 45903907:': 'phone', 'line-n.art7} aphb 43602625:': 'phone', 'line-n.w8_034:3995:': 'phone', 'line-n.w8_139:696:': 'phone', 'line-n.art7} aphb 20801955:': 'phone', 'line-n.w8_028:3156:': 'product', 'line-n.art7} aphb 19600919:': 'phone', 'line-n.w8_111:8071:': 'product', 'line-n.w7_041:4840:': 'product', 'line-n.w7_074:3928:': 'product', 'line-n.w8_049:15000:': 'product', 'line-n.w8_086:3306:': 'product', 'line-n.w9_8:1533:': 'product', 'line-n.w8_042:5289:': 'phone', 'line-n.w7_041:11151:': 'product', 'line-n.w7_059:9261:': 'phone', 'line-n.w9_6:10969:': 'phone', 'line-n.art7} aphb 41702230:': 'phone', 'line-n.w7_004:1365:': 'phone', 'line-n.art7} aphb 26902918:': 'phone', 'line-n.art7} aphb 37804749:': 'phone', 'line-n.w9_6:2907:': 'product', 'line-n.w7_106:10827:': 'product', 'line-n.art7} aphb 02400926:': 'phone', 'line-n.w7_107:12000:': 'phone', 'line-n.w7_087:620:': 'phone', 'line-n.art7} aphb 30203503:': 'phone', 'line-n.w9_40:10216:': 'product', 'line-n.art7} aphb 24500349:': 'phone', 'line-n.art7} aphb 02200986:': 'phone', 'line-n.w8_024:3051:': 'product', 'line-n.w7_023:17827:': 'phone', 'line-n.w8_142:13364:': 'phone', 'line-n.w8_083:14895:': 'phone', 'line-n.w7_117:10197:': 'phone', 'line-n.w8_013:14047:': 'phone', 'line-n.w7_019:14634:': 'phone', 'line-n.w7_017:6376:': 'phone', 'line-n.art7} aphb 24900680:': 'phone', 'line-n.w7_021:3496:': 'product', 'line-n.w9_13:9355:': 'phone', 'line-n.w8_098:13314:': 'product', 'line-n.w8_064:14051:': 'product', 'line-n.w7_107:7711:': 'phone', 'line-n.w9_40:10241:': 'product', 'line-n.w7_111:6250:': 'phone', 'line-n.w9_31:14204:': 'phone', 'line-n.w9_20:7066:': 'phone', 'line-n.w8_027:13714:': 'phone', 'line-n.w7_006:6674:': 'phone', 'line-n.w7_080:1471:': 'phone', 'line-n.w7_124:728:': 'product', 'line-n.w7_083:9304:': 'phone', 'line-n.w8_019:4936:': 'product', 'line-n.w9_17:14207:': 'product', 'line-n.w7_093:5547:': 'phone', 'line-n.w7_085:427:': 'phone', 'line-n.w7_112:2163:': 'product', 'line-n.w7_115:6602:': 'product', 'line-n.w8_081:8566:': 'phone', 'line-n.w8_104:2916:': 'product', 'line-n.w7_050:15645:': 'phone', 'line-n.w7_033:3398:': 'product', 'line-n.w9_8:3899:': 'phone', 'line-n.art7} aphb 37805623:': 'phone', 'line-n.w8_016:14692:': 'product', 'line-n.w7_107:826:': 'phone', 'line-n.w7_002:18532:': 'product', 'line-n.w7_102:12660:': 'phone', 'line-n.w8_002:7541:': 'phone', 'line-n.w8_063:10855:': 'product', 'line-n.art7} aphb 18601882:': 'phone', 'line-n.w9_7:13171:': 'product', 'line-n.w9_32:1867:': 'phone', 'line-n.w9_29:3437:': 'product', 'line-n.w7_019:18445:': 'phone', 'line-n.art7} aphb 45700442:': 'phone', 'line-n.w8_067:14552:': 'phone', 'line-n.w8_053:16416:': 'phone', 'line-n.w9_12:680:': 'product', 'line-n.w9_8:1503:': 'phone', 'line-n.w7_066:3322:': 'phone', 'line-n.w8_100:4429:': 'phone', 'line-n.w7_104:8687:': 'phone', 'line-n.art7} aphb 54101892:': 'product', 'line-n.w8_038:1345:': 'phone', 'line-n.w7_126:14239:': 'product', 'line-n.w9_30:3935:': 'product', 'line-n.w9_18:11863:': 'product', 'line-n.w8_003:16519:': 'product', 'line-n.art7} aphb 29604729:': 'phone', 'line-n.w9_38:10638:': 'product', 'line-n.w7_046:6144:': 'phone', 'line-n.w8_098:14382:': 'product', 'line-n.w8_074:4317:': 'phone', 'line-n.w7_011:18280:': 'phone', 'line-n.w8_053:3883:': 'phone', 'line-n.w8_040:16402:': 'phone', 'line-n.w7_065:13727:': 'product', 'line-n.w8_007:14740:': 'phone', 'line-n.w8_011:260:': 'phone', 'line-n.w7_003:8955:': 'phone', 'line-n.w8_011:298:': 'phone', 'line-n.w7_122:11595:': 'phone', 'line-n.w9_1:4358:': 'phone', 'line-n.w7_108:11591:': 'p ...

# %%
# read key and return dict mapping instance ids to their correct sense
def read_key_file(key_file):
    key = {}
    with open(key_file, 'r') as f:
        for line in f: 
            answer, instance_id, sense = line.strip().split()[0], line.strip().split()[1], line.strip().split()[2]
            key[instance_id[10:-1]] = sense[9:-3]
    return key

# read tagged file and return dict mapping instance ids to their predicted sense
def read_tagged_file(tagged_file):
    tagged = {}
    with open(tagged_file, 'r') as f:
        for line in f:
            answer, instance_id, sense = line.strip().split()[0], line.strip().split()[1], line.strip().split()[2]
            tagged[instance_id[10:-1]] = sense[9:-3]
    return tagged

# compare key and tagged dicts and return overall accuracy and confusion matrix
def evaluate(key, tagged):
    confusion_matrix = defaultdict(lambda: defaultdict(int))
    correct = 0
    total = len(key)
    for instance_id, key_sense in key.items():
        tagged_sense = tagged.get(instance_id)
        if not tagged_sense:
            continue
        confusion_matrix[key_sense][tagged_sense] += 1
        if tagged_sense == key_sense:
            correct += 1
    return (correct / total), confusion_matrix

## general path ##
"""if __name__ == '__main__':
    tagged_file = 'my-line-answers.txt'
    key_file = '/Users/viruthika/Desktop/line-answers.txt' 
    
    key = read_key_file(key_file)
    tagged = read_tagged_file(tagged_file)
    
    accuracy, confusion_matrix = evaluate(key, tagged)
    print('Accuracy:', accuracy)
    print('Confusion matrix:')
    for true_label in confusion_matrix:
        row = confusion_matrix[true_label]
        print(true_label, end='\t')
    print()"""

#change as needed for your file path
if __name__ == '__main__':
    desktop_path = '/Users/viruthika/Desktop'

    train_file = os.path.join(desktop_path, 'line-train.xml')
    test_file = os.path.join(desktop_path, 'line-test.xml')
    decision_list_file = os.path.join(desktop_path, 'my-line-answers.txt')
    predicted_labels_file = os.path.join(desktop_path, 'my-predicted-labels.txt')

    main(train_file, test_file, decision_list_file, predicted_labels_file)

    tagged_file = os.path.join(desktop_path, 'my-line-answers.txt')
    key_file = os.path.join(desktop_path, 'line-answers.txt')

    key = read_key_file(key_file)
    tagged = read_tagged_file(tagged_file)

    accuracy, confusion_matrix = evaluate(key, tagged)
    print('Accuracy:', accuracy)
    print('Confusion matrix:')
    for true_label in confusion_matrix:
        row = confusion_matrix[true_label]
        print(true_label, end='\t')
    print()
# Out:
# <bound method LidstoneProbDist.max of <ELEProbDist based on 0 samples>>
# 0.0034482758620689655
# Senses: phone
# 	Word: 5 Frequency: 1
# 	Word: access Frequency: 19
# 	Word: growth Frequency: 3
# 	Word: 000 Frequency: 8
# 	Word: new Frequency: 13
# 	Word: to Frequency: 21
# 	Word: on Frequency: 26
# 	Word: the Frequency: 77
# 	Word: gab Frequency: 8
# 	Word: have Frequency: 2
# 	Word: telephon Frequency: 42
# 	Word: tip Frequency: 3
# 	Word: that Frequency: 9
# 	Word: trader Frequency: 1
# 	Word: thousand Frequency: 2
# 	Word: keep Frequency: 3
# 	Word: busi Frequency: 5
# 	Word: residenti Frequency: 2
# 	Word: increas Frequency: 4
# 	Word: cellular Frequency: 1
# 	Word: mobil Frequency: 1
# 	Word: grew Frequency: 5
# 	Word: distanc Frequency: 1
# 	Word: or Frequency: 3
# 	Word: dedic Frequency: 3
# 	Word: make Frequency: 2
# 	Word: privat Frequency: 7
# 	Word: and Frequency: 26
# 	Word: switch Frequency: 1
# 	Word: was Frequency: 12
# 	Word: an Frequency: 4
# 	Word: outsid Frequency: 2
# 	Word: up Frequency: 1
# 	Word: but Frequency: 3
# 	Word: largest Frequency: 1
# 	Word: 371 Frequency: 1
# 	Word: instal Frequency: 2
# 	Word: over Frequency: 6
# 	Word: use Frequency: 2
# 	Word: as Frequency: 2
# 	Word: 24 Frequency: 1
# 	Word: 32 Frequency: 1
# 	Word: of Frequency: 18
# 	Word: s Frequency: 2
# 	Word: bisexu Frequency: 1
# 	Word: recent Frequency: 2
# 	Word: york Frequency: 1
# 	Word: free Frequency: 4
# 	Word: complaint Frequency: 1
# 	Word: necessari Frequency: 1
# 	Word: toll Frequency: 1
# 	Word: for Frequency: 9
# 	Word: their Frequency: 2
# 	Word: trade Frequency: 3
# 	Word: yesterday Frequency: 1
# 	Word: first Frequency: 1
# 	Word: off Frequency: 3
# 	Word: phone Frequency: 1
# 	Word: whose Frequency: 2
# 	Word: into Frequency: 1
# 	Word: open Frequency: 5
# 	Word: radio Frequency: 1
# 	Word: you Frequency: 1
# 	Word: unsecur Frequency: 1
# 	Word: while Frequency: 2
# 	Word: public Frequency: 1
# 	Word: is Frequency: 5
# 	Word: let Frequency: 1
# 	Word: see Frequency: 1
# 	Word: light Frequency: 1
# 	Word: when Frequency: 1
# 	Word: come Frequency: 1
# 	Word: pay Frequency: 1
# 	Word: subscrib Frequency: 3
# 	Word: charg Frequency: 3
# 	Word: four Frequency: 1
# 	Word: hullo Frequency: 1
# 	Word: were Frequency: 5
# 	Word: a Frequency: 13
# 	Word: dead Frequency: 1
# 	Word: fuqua Frequency: 1
# 	Word: provid Frequency: 1
# 	Word: fanci Frequency: 1
# 	Word: earthquak Frequency: 1
# 	Word: will Frequency: 1
# 	Word: 900 Frequency: 1
# 	Word: call Frequency: 2
# 	Word: other Frequency: 2
# 	Word: he Frequency: 1
# 	Word: custom Frequency: 3
# 	Word: clog Frequency: 4
# 	Word: just Frequency: 1
# 	Word: dozen Frequency: 1
# 	Word: at Frequency: 3
# 	Word: your Frequency: 1
# 	Word: direct Frequency: 5
# 	Word: no Frequency: 2
# 	Word: in Frequency: 12
# 	Word: resid Frequency: 1
# 	Word: calif Frequency: 1
# 	Word: onc Frequency: 1
# 	Word: dial Frequency: 1
# 	Word: 700 Frequency: 1
# 	Word: proprietor Frequency: 1
# 	Word: say Frequency: 4
# 	Word: went Frequency: 3
# 	Word: this Frequency: 1
# 	Word: lost Frequency: 1
# 	Word: from Frequency: 1
# 	Word: between Frequency: 1
# 	Word: 10 Frequency: 1
# 	Word: million Frequency: 3
# 	Word: if Frequency: 2
# 	Word: it Frequency: 1
# 	Word: said Frequency: 1
# 	Word: romanc Frequency: 1
# 	Word: 570 Frequency: 2
# 	Word: main Frequency: 2
# 	Word: i Frequency: 1
# 	Word: edmonton Frequency: 1
# 	Word: one Frequency: 2
# 	Word: quadrupl Frequency: 1
# 	Word: 866 Frequency: 1
# 	Word: all Frequency: 1
# 	Word: parti Frequency: 4
# 	Word: some Frequency: 1
# 	Word: certain Frequency: 1
# 	Word: local Frequency: 1
# 	Word: with Frequency: 2
# 	Word: cross Frequency: 1
# 	Word: by Frequency: 2
# 	Word: they Frequency: 2
# 	Word: becaus Frequency: 1
# 	Word: effect Frequency: 1
# 	Word: get Frequency: 2
# 	Word: voic Frequency: 2
# 	Word: anoth Frequency: 2
# 	Word: most Frequency: 1
# 	Word: import Frequency: 1
# 	Word: hardwar Frequency: 1
# 	Word: adapt Frequency: 1
# 	Word: grade Frequency: 1
# 	Word: 1200 Frequency: 1
# 	Word: 600 Frequency: 2
# 	Word: baud Frequency: 1
# 	Word: low Frequency: 1
# 	Word: speed Frequency: 1
# 	Word: 50 Frequency: 1
# 	Word: run Frequency: 1
# 	Word: last Frequency: 1
# 	Word: inform Frequency: 2
# 	Word: which Frequency: 2
# 	Word: through Frequency: 1
# 	Word: includ Frequency: 1
# 	Word: poorest Frequency: 1
# 	Word: so Frequency: 1
# 	Word: foreign Frequency: 1
# 	Word: exchang Frequency: 1
# 	Word: would Frequency: 1
# 	Word: his Frequency: 1
# 	Word: be Frequency: 1
# 	Word: sir Frequency: 1
# 	Word: like Frequency: 2
# 	Word: secur Frequency: 1
# 	Word: more Frequency: 1
# 	Word: accord Frequency: 1
# 	Word: hospit Frequency: 1
# 	Word: dure Frequency: 1
# 	Word: number Frequency: 1
# 	Word: hello Frequency: 1
# 	Word: 442 Frequency: 1
# 	Word: consum Frequency: 1
# 	Word: appeal Frequency: 1
# 	Word: sentenc Frequency: 1
# 	Word: mani Frequency: 1
# 	Word: among Frequency: 1
# 	Word: separ Frequency: 1
# 	Word: 3 Frequency: 1
# 	Word: extend Frequency: 1
# 	Word: seek Frequency: 1
# 	Word: fed Frequency: 1
# 	Word: transact Frequency: 1
# 	Word: also Frequency: 1
# 	Word: time Frequency: 1
# 	Word: asynchron Frequency: 1
# 	Word: check Frequency: 1
# 	Word: x Frequency: 1
# 	Word: rate Frequency: 1
# 	Word: station Frequency: 1
# 	Word: c Frequency: 1
# 	Word: 1 Frequency: 1
# 	Word: 800 Frequency: 1
# 	Word: three Frequency: 1
# 	Word: 911 Frequency: 1
# 	Word: emerg Frequency: 1
# 	Word: play Frequency: 1
# 	Word: noth Frequency: 1
# 	Word: sex Frequency: 1
# 	Word: chat Frequency: 2
# 	Word: ordinari Frequency: 1
# 	Word: jump Frequency: 1
# 	Word: those Frequency: 2
# 	Word: rent Frequency: 1
# 	Word: communic Frequency: 1
# 	Word: are Frequency: 1
# 	Word: nois Frequency: 1
# 	Word: singl Frequency: 1
# Senses: product
# 	Word: establish Frequency: 1
# 	Word: the Frequency: 30
# 	Word: as Frequency: 3
# 	Word: introduc Frequency: 5
# 	Word: in Frequency: 6
# 	Word: struggl Frequency: 1
# 	Word: was Frequency: 1
# 	Word: rang Frequency: 2
# 	Word: comput Frequency: 6
# 	Word: and Frequency: 19
# 	Word: previous Frequency: 1
# 	Word: three Frequency: 2
# 	Word: at Frequency: 4
# 	Word: higher Frequency: 1
# 	Word: margin Frequency: 1
# 	Word: which Frequency: 5
# 	Word: inc Frequency: 1
# 	Word: s Frequency: 21
# 	Word: of Frequency: 65
# 	Word: skin Frequency: 2
# 	Word: care Frequency: 3
# 	Word: is Frequency: 6
# 	Word: certain Frequency: 2
# 	Word: atlas Frequency: 1
# 	Word: furnitur Frequency: 1
# 	Word: could Frequency: 3
# 	Word: microprocessor Frequency: 2
# 	Word: non Frequency: 1
# 	Word: food Frequency: 4
# 	Word: rail Frequency: 1
# 	Word: intermod Frequency: 1
# 	Word: between Frequency: 1
# 	Word: car Frequency: 10
# 	Word: mr Frequency: 1
# 	Word: more Frequency: 1
# 	Word: complet Frequency: 2
# 	Word: luxuri Frequency: 2
# 	Word: may Frequency: 1
# 	Word: jaclyn Frequency: 2
# 	Word: smith Frequency: 2
# 	Word: frozen Frequency: 1
# 	Word: expand Frequency: 1
# 	Word: their Frequency: 1
# 	Word: said Frequency: 2
# 	Word: corp Frequency: 1
# 	Word: a Frequency: 35
# 	Word: similar Frequency: 2
# 	Word: r1 Frequency: 1
# 	Word: made Frequency: 1
# 	Word: launch Frequency: 2
# 	Word: truck Frequency: 1
# 	Word: through Frequency: 3
# 	Word: new Frequency: 15
# 	Word: ibm Frequency: 5
# 	Word: he Frequency: 2
# 	Word: produc Frequency: 3
# 	Word: two Frequency: 3
# 	Word: it Frequency: 24
# 	Word: integr Frequency: 1
# 	Word: popular Frequency: 2
# 	Word: diagnost Frequency: 1
# 	Word: show Frequency: 1
# 	Word: sever Frequency: 1
# 	Word: such Frequency: 2
# 	Word: compani Frequency: 2
# 	Word: volum Frequency: 1
# 	Word: creat Frequency: 1
# 	Word: by Frequency: 3
# 	Word: acquir Frequency: 2
# 	Word: to Frequency: 8
# 	Word: build Frequency: 3
# 	Word: into Frequency: 2
# 	Word: while Frequency: 1
# 	Word: will Frequency: 2
# 	Word: from Frequency: 5
# 	Word: older Frequency: 2
# 	Word: carleton Frequency: 1
# 	Word: brand Frequency: 1
# 	Word: other Frequency: 2
# 	Word: montana Frequency: 1
# 	Word: fragranc Frequency: 1
# 	Word: pc Frequency: 2
# 	Word: wouldn Frequency: 1
# 	Word: out Frequency: 1
# 	Word: aerospac Frequency: 1
# 	Word: seller Frequency: 1
# 	Word: gm Frequency: 2
# 	Word: 10 Frequency: 1
# 	Word: apparel Frequency: 1
# 	Word: that Frequency: 6
# 	Word: those Frequency: 1
# 	Word: were Frequency: 3
# 	Word: 5 Frequency: 1
# 	Word: billion Frequency: 1
# 	Word: cereal Frequency: 2
# 	Word: with Frequency: 4
# 	Word: own Frequency: 1
# 	Word: includ Frequency: 2
# 	Word: tri Frequency: 1
# 	Word: perfum Frequency: 1
# 	Word: elizabeth Frequency: 1
# 	Word: jeep Frequency: 1
# 	Word: 1988 Frequency: 1
# 	Word: model Frequency: 1
# 	Word: this Frequency: 1
# 	Word: brief Frequency: 1
# 	Word: current Frequency: 3
# 	Word: seek Frequency: 1
# 	Word: torpedo Frequency: 1
# 	Word: lastest Frequency: 1
# 	Word: market Frequency: 4
# 	Word: much Frequency: 1
# 	Word: broader Frequency: 1
# 	Word: but Frequency: 3
# 	Word: latest Frequency: 1
# 	Word: adult Frequency: 1
# 	Word: diaper Frequency: 1
# 	Word: most Frequency: 2
# 	Word: product Frequency: 10
# 	Word: particular Frequency: 1
# 	Word: materi Frequency: 2
# 	Word: fell Frequency: 2
# 	Word: florida Frequency: 1
# 	Word: these Frequency: 1
# 	Word: grand Frequency: 1
# 	Word: prix Frequency: 1
# 	Word: ps Frequency: 7
# 	Word: 2 Frequency: 8
# 	Word: his Frequency: 2
# 	Word: full Frequency: 2
# 	Word: under Frequency: 2
# 	Word: are Frequency: 3
# 	Word: cougar Frequency: 1
# 	Word: cracker Frequency: 1
# 	Word: drop Frequency: 1
# 	Word: dreamboat Frequency: 1
# 	Word: patch Frequency: 1
# 	Word: kid Frequency: 1
# 	Word: toy Frequency: 1
# 	Word: remain Frequency: 1
# 	Word: excav Frequency: 1
# 	Word: equip Frequency: 2
# 	Word: american Frequency: 1
# 	Word: tire Frequency: 1
# 	Word: 1 Frequency: 1
# 	Word: 69 Frequency: 1
# 	Word: midrang Frequency: 1
# 	Word: 400 Frequency: 1
# 	Word: menswear Frequency: 1
# 	Word: had Frequency: 1
# 	Word: jewelri Frequency: 1
# 	Word: athlet Frequency: 1
# 	Word: shoe Frequency: 1
# 	Word: 600 Frequency: 1
# 	Word: camera Frequency: 1
# 	Word: women Frequency: 1
# 	Word: where Frequency: 1
# 	Word: 32 Frequency: 1
# 	Word: built Frequency: 1
# 	Word: restaur Frequency: 1
# 	Word: sun Frequency: 1
# 	Word: choic Frequency: 1
# 	Word: softwar Frequency: 1
# 	Word: pace Frequency: 1
# 	Word: macintosh Frequency: 1
# 	Word: rose Frequency: 1
# 	Word: mirag Frequency: 1
# 	Word: amiga Frequency: 1
# 	Word: spectrum Frequency: 1
# 	Word: has Frequency: 2
# 	Word: ii Frequency: 1
# 	Word: move Frequency: 1
# 	Word: call Frequency: 1
# 	Word: old Frequency: 3
# 	Word: for Frequency: 6
# 	Word: ziari Frequency: 1
# 	Word: manufactur Frequency: 1
# 	Word: special Frequency: 1
# 	Word: broaden Frequency: 1
# 	Word: lexus Frequency: 1
# 	Word: upscal Frequency: 1
# 	Word: reap Frequency: 1
# 	Word: becaus Frequency: 2
# 	Word: minicomput Frequency: 1
# 	Word: along Frequency: 1
# 	Word: soft Frequency: 1
# 	Word: drink Frequency: 1
# 	Word: just Frequency: 1
# 	Word: offic Frequency: 1
# 	Word: chevrolet Frequency: 1
# 	Word: corsica Frequency: 1
# 	Word: credit Frequency: 2
# 	Word: bank Frequency: 1
# 	Word: discontinu Frequency: 1
# 	Word: loss Frequency: 1
# 	Word: consist Frequency: 1
# 	Word: specialti Frequency: 1
# 	Word: read Frequency: 1
# 	Word: last Frequency: 2
# 	Word: transform Frequency: 1
# 	Word: tonka Frequency: 1
# 	Word: pound Frequency: 1
# 	Word: puppi Frequency: 1
# 	Word: clarion Frequency: 1
# 	Word: have Frequency: 3
# 	Word: agricultur Frequency: 1
# 	Word: machineri Frequency: 1
# 	Word: all Frequency: 1
# 	Word: some Frequency: 3
# 	Word: dr Frequency: 1
# 	Word: denton Frequency: 1
# 	Word: lucrat Frequency: 1
# 	Word: militari Frequency: 1
# 	Word: georg Frequency: 1
# 	Word: long Frequency: 1
# 	Word: await Frequency: 1
# 	Word: basic Frequency: 1
# 	Word: chemic Frequency: 1
# 	Word: nail Frequency: 1
# 	Word: polish Frequency: 1
# 	Word: an Frequency: 1
# 	Word: exclus Frequency: 1
# 	Word: make Frequency: 2
# 	Word: main Frequency: 1
# 	Word: oh Frequency: 1
# 	Word: lantern Frequency: 1
# 	Word: 375 Frequency: 1
# 	Word: plan Frequency: 1
# 	Word: pw4000 Frequency: 1
# 	Word: start Frequency: 1
# 	Word: shed Frequency: 1
# 	Word: consum Frequency: 2
# 	Word: there Frequency: 1
# 	Word: person Frequency: 1
# 	Word: won Frequency: 1
# 	Word: sew Frequency: 1
# 	Word: they Frequency: 1
# 	Word: health Frequency: 1
# 	Word: club Frequency: 1
# 	Word: balli Frequency: 1
# 	Word: coleco Frequency: 1
# 	Word: drill Frequency: 1
# 	Word: bit Frequency: 1
# 	Word: baker Frequency: 1
# 	Word: zytel Frequency: 1
# 	Word: nation Frequency: 1
# 	Word: advertis Frequency: 1
# 	Word: initi Frequency: 1
# 	Word: filter Frequency: 1
# 	Word: vax Frequency: 2
# 	Word: cray Frequency: 1
# 	Word: reason Frequency: 1
# 	Word: price Frequency: 1
# 	Word: exist Frequency: 2
# 	Word: dps Frequency: 1
# 	Word: alreadi Frequency: 1
# 	Word: huge Frequency: 1
# 	Word: schaffner Frequency: 1
# 	Word: marx Frequency: 1
# 	Word: on Frequency: 1
# 	Word: so Frequency: 2
# 	Word: sell Frequency: 1
# 	Word: optometr Frequency: 1
# 	Word: ground Frequency: 1
# 	Word: coffe Frequency: 1
# 	Word: she Frequency: 1
# 	Word: level Frequency: 1
# 	Word: fox Frequency: 1
# 	Word: low Frequency: 1
# 	Word: calori Frequency: 1
# 	Word: sturdi Frequency: 1
# 	Word: 3x Frequency: 1
# 	Word: one Frequency: 1
# 	Word: test Frequency: 1
# 	Word: futur Frequency: 1
# 	Word: hormel Frequency: 1
# 	Word: anymor Frequency: 1
# 	Word: lancom Frequency: 1
# {'line-n.w8_059:8174:': 'phone', 'line-n.w7_098:12684:': 'phone', 'line-n.w8_106:13309:': 'phone', 'line-n.w9_40:10187:': 'phone', 'line-n.w9_16:217:': 'product', 'line-n.w8_119:16927:': 'product', 'line-n.w8_008:13756:': 'phone', 'line-n.w8_041:15186:': 'phone', 'line-n.art7} aphb 05601797:': 'phone', 'line-n.w8_119:2964:': 'phone', 'line-n.w7_040:13652:': 'phone', 'line-n.w7_122:2194:': 'phone', 'line-n.art7} aphb 45903907:': 'phone', 'line-n.art7} aphb 43602625:': 'phone', 'line-n.w8_034:3995:': 'phone', 'line-n.w8_139:696:': 'phone', 'line-n.art7} aphb 20801955:': 'phone', 'line-n.w8_028:3156:': 'product', 'line-n.art7} aphb 19600919:': 'phone', 'line-n.w8_111:8071:': 'product', 'line-n.w7_041:4840:': 'product', 'line-n.w7_074:3928:': 'product', 'line-n.w8_049:15000:': 'product', 'line-n.w8_086:3306:': 'product', 'line-n.w9_8:1533:': 'product', 'line-n.w8_042:5289:': 'phone', 'line-n.w7_041:11151:': 'product', 'line-n.w7_059:9261:': 'phone', 'line-n.w9_6:10969:': 'phone', 'line-n.art7} aphb 41702230:': 'phone', 'line-n.w7_004:1365:': 'phone', 'line-n.art7} aphb 26902918:': 'phone', 'line-n.art7} aphb 37804749:': 'phone', 'line-n.w9_6:2907:': 'product', 'line-n.w7_106:10827:': 'product', 'line-n.art7} aphb 02400926:': 'phone', 'line-n.w7_107:12000:': 'phone', 'line-n.w7_087:620:': 'phone', 'line-n.art7} aphb 30203503:': 'phone', 'line-n.w9_40:10216:': 'product', 'line-n.art7} aphb 24500349:': 'phone', 'line-n.art7} aphb 02200986:': 'phone', 'line-n.w8_024:3051:': 'product', 'line-n.w7_023:17827:': 'phone', 'line-n.w8_142:13364:': 'phone', 'line-n.w8_083:14895:': 'phone', 'line-n.w7_117:10197:': 'phone', 'line-n.w8_013:14047:': 'phone', 'line-n.w7_019:14634:': 'phone', 'line-n.w7_017:6376:': 'phone', 'line-n.art7} aphb 24900680:': 'phone', 'line-n.w7_021:3496:': 'product', 'line-n.w9_13:9355:': 'phone', 'line-n.w8_098:13314:': 'product', 'line-n.w8_064:14051:': 'product', 'line-n.w7_107:7711:': 'phone', 'line-n.w9_40:10241:': 'product', 'line-n.w7_111:6250:': 'phone', 'line-n.w9_31:14204:': 'phone', 'line-n.w9_20:7066:': 'phone', 'line-n.w8_027:13714:': 'phone', 'line-n.w7_006:6674:': 'phone', 'line-n.w7_080:1471:': 'phone', 'line-n.w7_124:728:': 'product', 'line-n.w7_083:9304:': 'phone', 'line-n.w8_019:4936:': 'product', 'line-n.w9_17:14207:': 'product', 'line-n.w7_093:5547:': 'phone', 'line-n.w7_085:427:': 'phone', 'line-n.w7_112:2163:': 'product', 'line-n.w7_115:6602:': 'product', 'line-n.w8_081:8566:': 'phone', 'line-n.w8_104:2916:': 'product', 'line-n.w7_050:15645:': 'phone', 'line-n.w7_033:3398:': 'product', 'line-n.w9_8:3899:': 'phone', 'line-n.art7} aphb 37805623:': 'phone', 'line-n.w8_016:14692:': 'product', 'line-n.w7_107:826:': 'phone', 'line-n.w7_002:18532:': 'product', 'line-n.w7_102:12660:': 'phone', 'line-n.w8_002:7541:': 'phone', 'line-n.w8_063:10855:': 'product', 'line-n.art7} aphb 18601882:': 'phone', 'line-n.w9_7:13171:': 'product', 'line-n.w9_32:1867:': 'phone', 'line-n.w9_29:3437:': 'product', 'line-n.w7_019:18445:': 'phone', 'line-n.art7} aphb 45700442:': 'phone', 'line-n.w8_067:14552:': 'phone', 'line-n.w8_053:16416:': 'phone', 'line-n.w9_12:680:': 'product', 'line-n.w9_8:1503:': 'phone', 'line-n.w7_066:3322:': 'phone', 'line-n.w8_100:4429:': 'phone', 'line-n.w7_104:8687:': 'phone', 'line-n.art7} aphb 54101892:': 'product', 'line-n.w8_038:1345:': 'phone', 'line-n.w7_126:14239:': 'product', 'line-n.w9_30:3935:': 'product', 'line-n.w9_18:11863:': 'product', 'line-n.w8_003:16519:': 'product', 'line-n.art7} aphb 29604729:': 'phone', 'line-n.w9_38:10638:': 'product', 'line-n.w7_046:6144:': 'phone', 'line-n.w8_098:14382:': 'product', 'line-n.w8_074:4317:': 'phone', 'line-n.w7_011:18280:': 'phone', 'line-n.w8_053:3883:': 'phone', 'line-n.w8_040:16402:': 'phone', 'line-n.w7_065:13727:': 'product', 'line-n.w8_007:14740:': 'phone', 'line-n.w8_011:260:': 'phone', 'line-n.w7_003:8955:': 'phone', 'line-n.w8_011:298:': 'phone', 'line-n.w7_122:11595:': 'phone', 'line-n.w9_1:4358:': 'phone', 'line-n.w7_108:11591:': 'p ...
# Accuracy: 0.0
# Confusion matrix:
